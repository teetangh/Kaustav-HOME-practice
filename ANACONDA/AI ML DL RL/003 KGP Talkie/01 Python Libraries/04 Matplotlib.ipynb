# %%
import numpy as np
import pandas as pd
from numpy.random import randint
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.linspace(1,10,20)
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y = randint(1,50,20)
y
# Out:
# array([24, 42, 40, 40, 37, 46, 30, 22, 47, 21, 22, 48, 20, 21, 35,  7, 47,
#        16, 35, 45])

# %%
y.size
# Out:
# 20

# %%
# dir(plt)  # Shows the complete list of functions available in matplotlib

# %%
plt.plot(y)

# %%
y=np.sort(y)
plt.plot(y)

# %%
# plt.plot(x,y,'g')
plt.plot(x,y,color = 'g')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Random Plot')
plt.show()

# %%
y2 = y * x

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'ro--',markersize=5)
plt.subplot(1,2,2)
plt.plot(x,y2,'b*')

# %% [markdown]
# # MATLAB vs matplotlib
# ## matplotlib can work like matlab as well as oop way

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,1,1])

axes.plot(x,y,'r')
# plt.xlabel('X')
# plt.ylabel('Y')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title("Set Title to Random")
# Out:
# Text(0.5, 1.0, 'Set Title to Random')

# %%
# dir(axes) # lists the availabe functions

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])  # Start(x,y) # Width(x,y)
ax2 = fig.add_axes([0.1,0.6,0.4,0.3])

ax1.plot(x,y,'r')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_title("Y Plot")

ax2.plot(x,y2,'g')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title("Y2 Plot")
# Out:
# Text(0.5, 1.0, 'Y2 Plot')

# %%
## plt.subplot()
## plt.subplots()

# %%
fig , ax = plt.subplots(1,2)

ax[0].plot(x,y,'b')
ax[1].plot(x,y2,'r')

# %%
fig , ax = plt.subplots(1,2)
col=['r','g']
data = [y,y2]

for i,axes in enumerate(ax):
    axes.plot(x,data[i],col[i])

fig.tight_layout()

# %%
fig,ax = plt.subplots(figsize = (6,4) , dpi = 100)
ax.plot(x,y,'r',label='y*x')
ax.plot(x,y2,'b',label='y2*x')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title("Random Number Plot")
ax.legend(loc=2) # 2nd Quadrant
fig.savefig("random file.png",dpi = 300)

# %%
fig,ax = plt.subplots()
ax.plot(x,y,'b2:',markersize = 6,linewidth = 2)
ax.plot(x,y2,'r,--',color='#058921')

# %%
fig,ax = plt.subplots(1,3,figsize=(12,4))

ax[0].plot(x,y,x,y2)

ax[1].plot(x,y**2,'k')  # k = black color
ax[1].set_ylim([0,3000])


ax[2].plot(x,y,x,y2)  # k = black color
ax[2].set_ylim([0,100])
ax[2].set_xlim([1,4])
# Out:
# (1.0, 4.0)

# %%
#  dir(plt)

# %%
plt.scatter(x,y)

# %%
plt.bar(y,height=1,width=0.5)
# Out:
# <BarContainer object of 20 artists>

# %%
from random import sample

# %%
data = sample(range(1,1000),10)
data
# Out:
# [848, 933, 896, 226, 29, 545, 169, 147, 690, 648]

# %%
plt.hist(data,rwidth = 0.8)
# Out:
# (array([1., 2., 1., 0., 0., 1., 1., 1., 0., 3.]),
#  array([ 29. , 119.4, 209.8, 300.2, 390.6, 481. , 571.4, 661.8, 752.2,
#         842.6, 933. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0,std,100) for std in range(1,10)]

# %%
plt.boxplot(data,vert=True,patch_artist=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x198f9958>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1992adc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x17c70b08>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1a1b7658>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x19b29928>,
# ...
#  'means': []}

# %%
plt.boxplot(data,vert=True,patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a249148>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a2494a8>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x1a1f8b68>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1a249940>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1a249ac0>,
# ...
#  'means': []}

# %% [markdown]
# # Advanced Matplotlib Concepts

# %%
fig,ax = plt.subplots(1,3,figsize=(15,5))

ax[0].plot(x,y,x,y2)

ax[1].plot(x,np.exp(x))
# ax[1].set_yscale('log')

ax[2].plot(x,np.exp(x))
ax[2].set_yscale('log')

fig.tight_layout()

# %%
fig,ax = plt.subplots(figsize=(10,5))

ax.plot(x,y2)

ax.set_xticks([1,3,5,10])
ax.set_xticklabels([r'$\alpha$',r'$\beta$',r'$\gamma$',r'$\delta$'],fontsize = 10)

ax.set_yticks([0,100,350,500])

# %%
from matplotlib import ticker

fig, ax = plt.subplots()
ax.plot(x,y2)
ax.set_title('Scientific Notation')

formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,-1))
ax.yaxis.set_major_formatter(formatter)
