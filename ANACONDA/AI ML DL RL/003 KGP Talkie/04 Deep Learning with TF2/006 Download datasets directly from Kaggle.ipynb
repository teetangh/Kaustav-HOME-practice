# %%
# !pip install -q kaggle
import kaggle

# !pip uninstall -y kaggle
# !pip install --upgrade pip
# !pip install kaggle==1.5.6
# !kaggle -v

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp "/content/drive/My Drive/Colab Notebooks/KGP Talkie DL/kaggle.json" ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !pip install --upgrade kaggle
# !pip install --upgrade --force-reinstall --no-deps kaggle

# Accept license
# !kaggle competitions download -c dogs-vs-cats
# Out:
# Downloading dogs-vs-cats.zip to /content
#  98% 793M/812M [00:08<00:00, 117MB/s]
# 100% 812M/812M [00:08<00:00, 101MB/s]

# %%
# !ls
# Out:
# dogs-vs-cats.zip  drive  sample_data

# %%
# !kaggle datasets list
# Out:
# ref                                                         title                                                 size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  --------------------------------------------------  ------  -------------------  -------------  ---------  ---------------
# allen-institute-for-ai/CORD-19-research-challenge           COVID-19 Open Research Dataset Challenge (CORD-19)     2GB  2020-05-02 20:35:01          62475       6248  0.88235295
# divyansh22/us-border-crossing-data                          US Border Crossing Data                                2MB  2020-04-19 09:38:10           1207         72  1.0
# roche-data-science-coalition/uncover                        UNCOVER COVID-19 Challenge                           142MB  2020-04-29 22:47:23           7263        588  0.8235294
# baltacifatih/turkish-lira-banknote-dataset                  Turkish Lira Banknote Dataset                          3GB  2020-04-19 14:48:39            112         27  0.9375
# doaaalsenani/usa-cers-dataset                               US Cars Dataset                                       66KB  2020-04-22 14:38:05           2092         86  1.0
# justinas/housing-in-london                                  Housing in London                                    169KB  2020-04-29 18:43:38           1274         67  1.0
# steveahn/memory-test-on-drugged-islanders-data              Memory Test on Drugged Islanders Data                  3KB  2019-08-20 18:54:37            747         36  1.0
# phiitm/reddit-india-flair-detector                          Reddit India Flair Detector                           48MB  2020-04-27 20:27:24             69         10  1.0
# ankurzing/sentiment-analysis-for-financial-news             Sentiment Analysis for Financial News                904KB  2020-04-26 18:41:22            401         31  1.0
# slayomer/forbes-celebrity-100-since-2005                    Forbes Celebrity 100 since 2005 (for Racing Bar)      12KB  2020-04-26 15:51:16            273         20  1.0
# mariaren/covid19-healthy-diet-dataset                       COVID-19 Healthy Diet Dataset                         82KB  2020-05-06 17:23:37           1019         50  1.0
# jessemostipak/animal-crossing                               Animal Crossing                                      754KB  2020-05-04 15:30:32             67         14  0.88235295
# marcelopesse/cartier-jewelry-catalog                        Cartier Jewelry - Catalog                             22KB  2020-04-27 05:03:23            149          6  1.0
# benroshan/factors-affecting-campus-placement                Campus Recruitment                                     5KB  2020-04-11 11:09:02           3041         95  1.0
# bobbyscience/league-of-legends-diamond-ranked-games-10-min  League of Legends Diamond Ranked Games (10 min)      539KB  2020-04-13 13:53:02           1445        107  1.0
# fireballbyedimyrnmom/us-counties-covid-19-dataset           US counties COVID 19 dataset                        1022KB  2020-05-06 12:22:25           6034        199  0.9411765
# divyansh22/flight-delay-prediction                          January Flight Delay Prediction                       23MB  2020-04-14 13:15:41           1237         53  1.0
# clmentbisaillon/fake-and-real-news-dataset                  Fake and real news dataset                            41MB  2020-03-26 18:51:15           3112        176  1.0
# ikiulian/global-hospital-beds-capacity-for-covid19          Global Hospital Beds Capacity (for covid-19)         284KB  2020-04-26 09:39:35           1472         41  1.0
# praveengovi/coronahack-chest-xraydataset                    CoronaHack -Chest X-Ray-Dataset                        1GB  2020-03-20 01:26:40           2061        125  0.9411765
